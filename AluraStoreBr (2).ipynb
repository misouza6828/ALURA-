# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
loja.columns
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')

# %%
faturamento1 = loja['Preço'].sum()
faturamento2 = loja2['Preço'].sum()
faturamento3 = loja3['Preço'].sum()
faturamento4 = loja4['Preço'].sum()

print(f'Faturamento Loja 1: R$ {faturamento1:.2f}')
print(f'Faturamento Loja 2: R$ {faturamento2:.2f}')
print(f'Faturamento Loja 3: R$ {faturamento3:.2f}')
print(f'Faturamento Loja 4: R$ {faturamento4:.2f}')
# Out:
# Faturamento Loja 1: R$ 1534509.12
# Faturamento Loja 2: R$ 1488459.06
# Faturamento Loja 3: R$ 1464025.03
# Faturamento Loja 4: R$ 1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
cat_popular_loja = loja['Categoria do Produto'].value_counts().idxmax()
cat_popular_loja2 = loja2['Categoria do Produto'].value_counts().idxmax()
cat_popular_loja3 = loja3['Categoria do Produto'].value_counts().idxmax()
cat_popular_loja4 = loja4['Categoria do Produto'].value_counts().idxmax()

print('Categoria mais popular Loja:', cat_popular_loja)
print('Categoria mais popular Loja2:', cat_popular_loja2)
print('Categoria mais popular Loja3:', cat_popular_loja3)
print('Categoria mais popular Loja4:', cat_popular_loja4)
# Out:
# Categoria mais popular Loja: moveis
# Categoria mais popular Loja2: moveis
# Categoria mais popular Loja3: moveis
# Categoria mais popular Loja4: moveis

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
media_avaliacao_loja = loja['Avaliação da compra'].mean()
media_avaliacao_loja2 = loja2['Avaliação da compra'].mean()
media_avaliacao_loja3 = loja3['Avaliação da compra'].mean()
media_avaliacao_loja4 = loja4['Avaliação da compra'].mean()

print(media_avaliacao_loja, media_avaliacao_loja2, media_avaliacao_loja3, media_avaliacao_loja4)
# Out:
# 3.976685036032217 4.037303942348453 4.048325561678677 3.9957591178965224

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
mais_vendido_loja = loja['Produto'].value_counts().idxmax()
menos_vendido_loja = loja['Produto'].value_counts().idxmin()

mais_vendido_loja2 = loja2['Produto'].value_counts().idxmax()
menos_vendido_loja2 = loja2['Produto'].value_counts().idxmin()

mais_vendido_loja3 = loja3['Produto'].value_counts().idxmax()
menos_vendido_loja3 = loja3['Produto'].value_counts().idxmin()

mais_vendido_loja4 = loja4['Produto'].value_counts().idxmax()
menos_vendido_loja4 = loja4['Produto'].value_counts().idxmin()

print(mais_vendido_loja, menos_vendido_loja)
print(mais_vendido_loja2, menos_vendido_loja2)
print(mais_vendido_loja3, menos_vendido_loja3)
print(mais_vendido_loja4, menos_vendido_loja4)
# Out:
# Micro-ondas Headset
# Iniciando em programação Jogo de tabuleiro
# Kit banquetas Blocos de montar
# Cama box Guitarra

# %%
print(loja['Produto'].value_counts().head(5))
print(loja2['Produto'].value_counts().head(5))
print(loja3['Produto'].value_counts().head(5))
print(loja4['Produto'].value_counts().head(5))
# Out:
# Produto
# Micro-ondas           60
# TV Led UHD 4K         60
# Guarda roupas         60
# Secadora de roupas    58
# Cômoda                56
# Name: count, dtype: int64
# Produto
# Iniciando em programação    65
# Micro-ondas                 62
# Bateria                     61
# Violão                      58
# Pandeiro                    58
# Name: count, dtype: int64
# Produto
# Kit banquetas      57
# Mesa de jantar     56
# Cama king          56
# Jogo de panelas    55
# Cômoda             55
# Name: count, dtype: int64
# Produto
# Cama box                    62
# Faqueiro                    59
# Dashboards com Power BI     56
# Cama king                   56
# Carrinho controle remoto    55
# Name: count, dtype: int64

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_medio_loja = loja['Frete'].mean()
frete_medio_loja2 = loja2['Frete'].mean()
frete_medio_loja3 = loja3['Frete'].mean()
frete_medio_loja4 = loja4['Frete'].mean()
print(frete_medio_loja, frete_medio_loja2, frete_medio_loja3, frete_medio_loja4)
# Out:
# 34.69180491551149 33.62194065817927 33.07446427411743 31.278997081841727

# %% [markdown]
# Gráficos

# %%
produtos_mais_vendidos = loja['Produto'].value_counts().head(5)

plt.figure(figsize=(8,5))
produtos_mais_vendidos.plot(kind='barh', color='orange')
plt.title('Top 5 Produtos Mais Vendidos - Loja 1')
plt.xlabel('Quantidade Vendida')
plt.ylabel('Produto')
plt.gca().invert_yaxis()  # deixa o mais vendido no topo
plt.show()

# %%
# Juntando as 4 lojas
import pandas as pd

todas_lojas = pd.concat([loja, loja2, loja3, loja4])
categorias = todas_lojas['Categoria do Produto'].value_counts()

# Gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(categorias, labels=categorias.index, autopct='%1.1f%%', startangle=140)
plt.title('Categorias Mais Vendidas (Todas as Lojas)')
plt.axis('equal')
plt.show()

# %%
avaliacao_loja1 = loja['Avaliação da compra'].mean()
avaliacao_loja2 = loja2['Avaliação da compra'].mean()
avaliacao_loja3 = loja3['Avaliação da compra'].mean()
avaliacao_loja4 = loja4['Avaliação da compra'].mean()

avaliacoes = [avaliacao_loja1, avaliacao_loja2, avaliacao_loja3, avaliacao_loja4]
lojas = ['Loja1', 'Loja2', 'Loja3', 'Loja4']

plt.bar(lojas, avaliacoes, color='lightcoral')
plt.xlabel('Lojas')
plt.ylabel('Média de Avaliação')
plt.title('Média de Avaliação dos Clientes por Loja')
plt.ylim(0, 5)
plt.show()

# %%
import seaborn as sns

dados_frete = [
    loja['Frete'],
    loja2['Frete'],
    loja3['Frete'],
    loja4['Frete']
]

plt.figure(figsize=(8,5))
sns.boxplot(data=dados_frete)
plt.xticks([0,1,2,3], ['Loja1', 'Loja2', 'Loja3', 'Loja4'])
plt.title('Comparação do Frete por Loja')
plt.ylabel('Valor do Frete')
plt.grid(True)
plt.show()
